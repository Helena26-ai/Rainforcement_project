# %% [markdown]
# <a href="https://colab.research.google.com/github/Helena26-ai/Rainforcement_project/blob/Helena/Dueling_DQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium[atari,accept-rom-license]==0.29.1
# Out:
# Collecting gymnasium==0.29.1 (from gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->gymnasium[accept-rom-license,atari]==0.29.1) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->gymnasium[accept-rom-license,atari]==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->gymnasium[accept-rom-license,atari]==0.29.1) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->gymnasium[accept-rom-license,atari]==0.29.1) (0.0.4)
# Collecting autorom~=0.4.2 (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading AutoROM-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting shimmy<1.0,>=0.1.0 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading Shimmy-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (8.1.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (4.67.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 17.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading ale_py-0.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[accept-rom-license,atari]==0.29.1) (6.5.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (2025.4.26)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 35.0 MB/s eta 0:00:00
# Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Downloading ale_py-0.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.8 MB/s eta 0:00:00
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446710 sha256=24b38f4ed9fecc115cd243a29d38d45c186507d7ae9805ade4a1e2a95f8d64fa
#   Stored in directory: /root/.cache/pip/wheels/bc/fc/c6/8aa657c0d2089982f2dabd110efc68c61eb49831fdb7397351
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: gymnasium, ale-py, shimmy, AutoROM.accept-rom-license, autorom
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.1.1
#     Uninstalling gymnasium-1.1.1:
#       Successfully uninstalled gymnasium-1.1.1
#   Attempting uninstall: ale-py
#     Found existing installation: ale-py 0.11.0
#     Uninstalling ale-py-0.11.0:
#       Successfully uninstalled ale-py-0.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.4.2 gymnasium-0.29.1 shimmy-0.2.1

# %%
# !pip install stable-baselines3 tensorboard matplotlib -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.7 MB/s eta 0:00:00

# %%
# DUELING DQN implementation for Pong
import os
import gymnasium as gym
from gymnasium import spaces
import collections
import typing as tt
import numpy as np
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard.writer import SummaryWriter
from gymnasium.wrappers import RecordVideo
import matplotlib.pyplot as plt
from stable_baselines3.common.atari_wrappers import AtariWrapper
from dataclasses import dataclass

# %%
os.makedirs("my_runs", exist_ok=True)
os.makedirs("my_runs/video", exist_ok=True)

# %%
# ==== DUELING DQN MODEL ====
class DuelingDQN(nn.Module):
    def __init__(self, input_shape: tt.Tuple[int, ...], n_actions: int):
        super(DuelingDQN, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten()
        )
        conv_out_size = self.conv(torch.zeros(1, *input_shape)).shape[1]
        self.fc_adv = nn.Sequential(
            nn.Linear(conv_out_size, 256),
            nn.ReLU(),
            nn.Linear(256, n_actions)
        )
        self.fc_val = nn.Sequential(
            nn.Linear(conv_out_size, 256),
            nn.ReLU(),
            nn.Linear(256, 1)
        )

    def forward(self, x):
        x = x.float() / 255.0
        conv_out = self.conv(x)
        adv = self.fc_adv(conv_out)
        val = self.fc_val(conv_out)
        return val + (adv - adv.mean(dim=1, keepdim=True))

    #def adv_val(self, x):
     #   x = x.float() / 255.0
      #  conv_out = self.conv(x)
       # return self.fc_adv(conv_out), self.fc_val(conv_out)

# %%
# === WRAPPERS ===
class ImageToPyTorch(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        obs = self.observation_space
        self.observation_space = spaces.Box(
            low=obs.low.min(), high=obs.high.max(),
            shape=(obs.shape[2], obs.shape[0], obs.shape[1]), dtype=obs.dtype)

    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)

class BufferWrapper(gym.ObservationWrapper):
    def __init__(self, env, n_steps):
        super().__init__(env)
        self.buffer = collections.deque(maxlen=n_steps)
        obs = env.observation_space
        self.observation_space = spaces.Box(
            low=np.repeat(obs.low, n_steps, axis=0),
            high=np.repeat(obs.high, n_steps, axis=0),
            dtype=obs.dtype)

    def reset(self, **kwargs):
        for _ in range(self.buffer.maxlen - 1):
            self.buffer.append(self.env.observation_space.low)
        obs, info = self.env.reset(**kwargs)
        return self.observation(obs), info

    def observation(self, observation):
        self.buffer.append(observation)
        return np.concatenate(self.buffer)

def make_env(env_name: str, **kwargs):
    env = gym.make(env_name, **kwargs)
    env = AtariWrapper(env, clip_reward=False, noop_max=0)
    env = ImageToPyTorch(env)
    env = BufferWrapper(env, n_steps=4)
    return env

# %%
# === PARAMS ===
DEFAULT_ENV_NAME = "PongNoFrameskip-v4"
MEAN_REWARD_BOUND = 19
GAMMA = 0.99
BATCH_SIZE = 32
REPLAY_SIZE = 10000
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 1000
REPLAY_START_SIZE = 10000
EPSILON_DECAY_LAST_FRAME = 150000
EPSILON_START = 1.0
EPSILON_FINAL = 0.01

@dataclass
class Experience:
    state: np.ndarray
    action: int
    reward: float
    done_trunc: bool
    new_state: np.ndarray

class ExperienceBuffer:
    def __init__(self, capacity: int):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience: Experience):
        self.buffer.append(experience)

    def sample(self, batch_size: int) -> list:
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        return [self.buffer[idx] for idx in indices]

class Agent:
    def __init__(self, env: gym.Env, exp_buffer: ExperienceBuffer):
        self.env = env
        self.exp_buffer = exp_buffer
        self.state = None
        self.total_reward = 0.0
        self._reset()

    def _reset(self):
        self.state, _ = self.env.reset()
        self.total_reward = 0.0

    @torch.no_grad()
    def play_step(self, net: DuelingDQN, device: torch.device, epsilon=0.0):
        if np.random.random() < epsilon:
            action = self.env.action_space.sample()
        else:
            state_v = torch.tensor(np.array([self.state]), device=device)
            q_vals = net(state_v)
            action = torch.argmax(q_vals).item()

        new_state, reward, done, trunc, _ = self.env.step(action)
        self.total_reward += reward
        self.exp_buffer.append(Experience(self.state, action, reward, done or trunc, new_state))
        self.state = new_state

        if done or trunc:
            r = self.total_reward
            self._reset()
            return r
        return None

def batch_to_tensors(batch, device):
    states = torch.tensor(np.array([e.state for e in batch]), device=device)
    actions = torch.tensor([e.action for e in batch], dtype=torch.long, device=device)
    rewards = torch.tensor([e.reward for e in batch], dtype=torch.float32, device=device)
    dones = torch.tensor([e.done_trunc for e in batch], dtype=torch.bool, device=device)
    next_states = torch.tensor(np.array([e.new_state for e in batch]), device=device)
    return states, actions, rewards, dones, next_states

def calc_loss(batch, net, tgt_net, device):
    states, actions, rewards, dones, next_states = batch_to_tensors(batch, device)
    state_action_values = net(states).gather(1, actions.unsqueeze(-1)).squeeze(-1)
    with torch.no_grad():
        next_state_values = tgt_net(next_states).max(1)[0]
        next_state_values[dones] = 0.0
    expected_values = rewards + GAMMA * next_state_values
    return nn.MSELoss()(state_action_values, expected_values)

# %%
# === TRAIN ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
env = make_env(DEFAULT_ENV_NAME)
net = DuelingDQN(env.observation_space.shape, env.action_space.n).to(device)
tgt_net = DuelingDQN(env.observation_space.shape, env.action_space.n).to(device)
buffer = ExperienceBuffer(REPLAY_SIZE)
agent = Agent(env, buffer)
optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
writer = SummaryWriter(log_dir="my_runs")

epsilon = EPSILON_START
frame_idx = 0
best_mean_reward = None
rewards = []
ts = time.time()
ts_frame = 0

while True:
    frame_idx += 1
    epsilon = max(EPSILON_FINAL, EPSILON_START - frame_idx / EPSILON_DECAY_LAST_FRAME)
    reward = agent.play_step(net, device, epsilon)
    if reward is not None:
        rewards.append(reward)
        speed = (frame_idx - ts_frame) / (time.time() - ts)
        ts_frame = frame_idx
        ts = time.time()
        m_reward = np.mean(rewards[-100:])
        print(f"{frame_idx}: games {len(rewards)}, reward {m_reward:.3f}, eps {epsilon:.2f}, speed {speed:.2f} f/s")
        writer.add_scalar("epsilon", epsilon, frame_idx)
        writer.add_scalar("speed", speed, frame_idx)
        writer.add_scalar("reward_100", m_reward, frame_idx)
        writer.add_scalar("reward", reward, frame_idx)

        if best_mean_reward is None or best_mean_reward < m_reward:
            torch.save(net.state_dict(), f"my_runs/best_{m_reward:.0f}.dat")
            best_mean_reward = m_reward
        if m_reward > MEAN_REWARD_BOUND:
            print("Solved!")
            break

    if len(buffer) < REPLAY_START_SIZE:
        continue

    if frame_idx % SYNC_TARGET_FRAMES == 0:
        tgt_net.load_state_dict(net.state_dict())

    batch = buffer.sample(BATCH_SIZE)
    optimizer.zero_grad()
    loss = calc_loss(batch, net, tgt_net, device)
    loss.backward()
    optimizer.step()

writer.close()
# Out:
# 852: games 1, reward -21.000, eps 0.99, speed 587.81 f/s
# 1730: games 2, reward -21.000, eps 0.99, speed 824.56 f/s
# 2739: games 3, reward -20.667, eps 0.98, speed 818.86 f/s
# 3563: games 4, reward -20.750, eps 0.98, speed 819.11 f/s
# 4431: games 5, reward -20.600, eps 0.97, speed 814.95 f/s
# 5696: games 6, reward -20.333, eps 0.96, speed 782.37 f/s
# 6486: games 7, reward -20.429, eps 0.96, speed 787.73 f/s
# 7489: games 8, reward -20.375, eps 0.95, speed 779.50 f/s
# 8435: games 9, reward -20.222, eps 0.94, speed 772.21 f/s
# 9272: games 10, reward -20.300, eps 0.94, speed 790.76 f/s
# 10212: games 11, reward -20.364, eps 0.93, speed 319.74 f/s
# 11052: games 12, reward -20.333, eps 0.93, speed 148.70 f/s
# 11992: games 13, reward -20.385, eps 0.92, speed 148.28 f/s
# 12783: games 14, reward -20.429, eps 0.91, speed 149.53 f/s
# 13792: games 15, reward -20.400, eps 0.91, speed 146.60 f/s
# 14610: games 16, reward -20.438, eps 0.90, speed 147.08 f/s
# 15538: games 17, reward -20.412, eps 0.90, speed 147.35 f/s
# 16390: games 18, reward -20.444, eps 0.89, speed 148.83 f/s
# 17359: games 19, reward -20.474, eps 0.88, speed 151.30 f/s
# 18327: games 20, reward -20.500, eps 0.88, speed 148.45 f/s
# 19448: games 21, reward -20.476, eps 0.87, speed 148.22 f/s
# 20288: games 22, reward -20.455, eps 0.86, speed 147.27 f/s
# 21300: games 23, reward -20.435, eps 0.86, speed 149.75 f/s
# 22206: games 24, reward -20.458, eps 0.85, speed 148.32 f/s
# 23154: games 25, reward -20.480, eps 0.85, speed 146.09 f/s
# 24037: games 26, reward -20.500, eps 0.84, speed 146.21 f/s
# 25055: games 27, reward -20.519, eps 0.83, speed 146.12 f/s
# 25924: games 28, reward -20.500, eps 0.83, speed 148.21 f/s
# 26872: games 29, reward -20.483, eps 0.82, speed 144.97 f/s
# 27771: games 30, reward -20.500, eps 0.81, speed 145.97 f/s
# 28552: games 31, reward -20.516, eps 0.81, speed 143.05 f/s
# 29393: games 32, reward -20.500, eps 0.80, speed 144.52 f/s
# 30370: games 33, reward -20.485, eps 0.80, speed 144.32 f/s
# 31211: games 34, reward -20.500, eps 0.79, speed 145.86 f/s
# 32051: games 35, reward -20.486, eps 0.79, speed 145.22 f/s
# 32887: games 36, reward -20.472, eps 0.78, speed 146.76 f/s
# 33751: games 37, reward -20.459, eps 0.77, speed 145.53 f/s
# 34768: games 38, reward -20.447, eps 0.77, speed 145.05 f/s
# 35604: games 39, reward -20.436, eps 0.76, speed 141.79 f/s
# 36502: games 40, reward -20.425, eps 0.76, speed 142.00 f/s
# 37546: games 41, reward -20.415, eps 0.75, speed 146.30 f/s
# 38565: games 42, reward -20.405, eps 0.74, speed 144.55 f/s
# 39604: games 43, reward -20.395, eps 0.74, speed 146.11 f/s
# 40601: games 44, reward -20.364, eps 0.73, speed 143.73 f/s
# 41768: games 45, reward -20.333, eps 0.72, speed 145.21 f/s
# 42821: games 46, reward -20.326, eps 0.71, speed 146.17 f/s
# 43746: games 47, reward -20.319, eps 0.71, speed 143.62 f/s
# 44819: games 48, reward -20.312, eps 0.70, speed 144.62 f/s
# 46008: games 49, reward -20.306, eps 0.69, speed 144.04 f/s
# 46849: games 50, reward -20.300, eps 0.69, speed 143.76 f/s
# 47924: games 51, reward -20.275, eps 0.68, speed 145.84 f/s
# 49029: games 52, reward -20.269, eps 0.67, speed 143.66 f/s
# 50120: games 53, reward -20.264, eps 0.67, speed 141.64 f/s
# 51257: games 54, reward -20.241, eps 0.66, speed 141.39 f/s
# 52265: games 55, reward -20.236, eps 0.65, speed 140.13 f/s
# 53341: games 56, reward -20.214, eps 0.64, speed 139.23 f/s
# 54398: games 57, reward -20.193, eps 0.64, speed 139.10 f/s
# 55727: games 58, reward -20.172, eps 0.63, speed 140.71 f/s
# 56766: games 59, reward -20.153, eps 0.62, speed 141.19 f/s
# 57930: games 60, reward -20.117, eps 0.61, speed 141.65 f/s
# 59145: games 61, reward -20.115, eps 0.61, speed 140.40 f/s
# 60358: games 62, reward -20.113, eps 0.60, speed 142.77 f/s
# 61493: games 63, reward -20.079, eps 0.59, speed 140.32 f/s
# 62500: games 64, reward -20.078, eps 0.58, speed 141.30 f/s
# 63822: games 65, reward -20.062, eps 0.57, speed 141.69 f/s
# 64612: games 66, reward -20.076, eps 0.57, speed 138.02 f/s
# 65753: games 67, reward -20.075, eps 0.56, speed 141.24 f/s
# 67026: games 68, reward -20.015, eps 0.55, speed 139.75 f/s
# 68303: games 69, reward -19.986, eps 0.54, speed 139.29 f/s
# 69916: games 70, reward -19.900, eps 0.53, speed 138.77 f/s
# 71064: games 71, reward -19.887, eps 0.53, speed 135.96 f/s
# 72416: games 72, reward -19.861, eps 0.52, speed 136.44 f/s
# 73702: games 73, reward -19.849, eps 0.51, speed 137.45 f/s
# 75018: games 74, reward -19.838, eps 0.50, speed 134.43 f/s
# 76547: games 75, reward -19.800, eps 0.49, speed 136.24 f/s
# 78057: games 76, reward -19.789, eps 0.48, speed 136.28 f/s
# 79539: games 77, reward -19.792, eps 0.47, speed 138.45 f/s
# 80615: games 78, reward -19.795, eps 0.46, speed 137.50 f/s
# 82039: games 79, reward -19.772, eps 0.45, speed 135.28 f/s
# 83341: games 80, reward -19.775, eps 0.44, speed 135.88 f/s
# 84754: games 81, reward -19.765, eps 0.43, speed 137.68 f/s
# 86172: games 82, reward -19.756, eps 0.43, speed 138.70 f/s
# 88115: games 83, reward -19.711, eps 0.41, speed 134.87 f/s
# 89356: games 84, reward -19.714, eps 0.40, speed 137.20 f/s
# 90996: games 85, reward -19.671, eps 0.39, speed 137.96 f/s
# 92370: games 86, reward -19.663, eps 0.38, speed 136.59 f/s
# 94108: games 87, reward -19.632, eps 0.37, speed 135.37 f/s
# 95750: games 88, reward -19.614, eps 0.36, speed 135.72 f/s
# 97341: games 89, reward -19.584, eps 0.35, speed 135.41 f/s
# 99234: games 90, reward -19.533, eps 0.34, speed 134.08 f/s
# 100732: games 91, reward -19.516, eps 0.33, speed 135.95 f/s
# 102224: games 92, reward -19.500, eps 0.32, speed 136.00 f/s
# 103951: games 93, reward -19.484, eps 0.31, speed 134.02 f/s
# 105857: games 94, reward -19.457, eps 0.29, speed 135.41 f/s
# 107654: games 95, reward -19.411, eps 0.28, speed 133.66 f/s
# 109063: games 96, reward -19.417, eps 0.27, speed 134.47 f/s
# 110414: games 97, reward -19.402, eps 0.26, speed 132.66 f/s
# 112211: games 98, reward -19.367, eps 0.25, speed 133.26 f/s
# 114103: games 99, reward -19.333, eps 0.24, speed 133.14 f/s
# 116075: games 100, reward -19.320, eps 0.23, speed 132.88 f/s
# 117911: games 101, reward -19.280, eps 0.21, speed 134.20 f/s
# 119832: games 102, reward -19.240, eps 0.20, speed 131.96 f/s
# 121780: games 103, reward -19.200, eps 0.19, speed 131.42 f/s
# 124216: games 104, reward -19.120, eps 0.17, speed 131.82 f/s
# 126335: games 105, reward -19.050, eps 0.16, speed 130.92 f/s
# 127992: games 106, reward -19.040, eps 0.15, speed 131.39 f/s
# 130276: games 107, reward -18.940, eps 0.13, speed 130.48 f/s
# 131973: games 108, reward -18.910, eps 0.12, speed 132.73 f/s
# 134082: games 109, reward -18.900, eps 0.11, speed 131.95 f/s
# 137081: games 110, reward -18.780, eps 0.09, speed 129.79 f/s
# 139727: games 111, reward -18.710, eps 0.07, speed 128.53 f/s
# 142688: games 112, reward -18.600, eps 0.05, speed 130.42 f/s
# 145984: games 113, reward -18.480, eps 0.03, speed 130.06 f/s
# 149643: games 114, reward -18.330, eps 0.01, speed 130.99 f/s
# 153379: games 115, reward -18.150, eps 0.01, speed 127.93 f/s
# 157899: games 116, reward -17.950, eps 0.01, speed 130.36 f/s
# 161357: games 117, reward -17.840, eps 0.01, speed 129.98 f/s
# 164922: games 118, reward -17.620, eps 0.01, speed 128.81 f/s
# 168142: games 119, reward -17.480, eps 0.01, speed 129.26 f/s
# 170762: games 120, reward -17.370, eps 0.01, speed 130.89 f/s
# 173858: games 121, reward -17.210, eps 0.01, speed 130.50 f/s
# 177154: games 122, reward -17.050, eps 0.01, speed 130.03 f/s
# 180698: games 123, reward -16.820, eps 0.01, speed 129.11 f/s
# 184321: games 124, reward -16.620, eps 0.01, speed 130.86 f/s
# 187914: games 125, reward -16.390, eps 0.01, speed 129.65 f/s
# 192093: games 126, reward -16.190, eps 0.01, speed 128.59 f/s
# 195888: games 127, reward -15.960, eps 0.01, speed 129.23 f/s
# 200375: games 128, reward -15.810, eps 0.01, speed 129.41 f/s
# 203656: games 129, reward -15.660, eps 0.01, speed 128.59 f/s
# 207572: games 130, reward -15.470, eps 0.01, speed 128.82 f/s
# 210696: games 131, reward -15.310, eps 0.01, speed 130.08 f/s
# 214620: games 132, reward -15.060, eps 0.01, speed 128.42 f/s
# 218269: games 133, reward -14.810, eps 0.01, speed 129.93 f/s
# 222007: games 134, reward -14.620, eps 0.01, speed 130.01 f/s
# 226071: games 135, reward -14.350, eps 0.01, speed 129.46 f/s
# 229617: games 136, reward -14.160, eps 0.01, speed 127.40 f/s
# 233026: games 137, reward -13.880, eps 0.01, speed 128.03 f/s
# 236523: games 138, reward -13.660, eps 0.01, speed 129.21 f/s
# 239836: games 139, reward -13.410, eps 0.01, speed 129.24 f/s
# 243554: games 140, reward -13.180, eps 0.01, speed 128.84 f/s
# 245652: games 141, reward -12.810, eps 0.01, speed 129.57 f/s
# 248516: games 142, reward -12.490, eps 0.01, speed 130.17 f/s
# 250836: games 143, reward -12.130, eps 0.01, speed 128.95 f/s
# 253593: games 144, reward -11.810, eps 0.01, speed 129.95 f/s
# 255757: games 145, reward -11.440, eps 0.01, speed 131.34 f/s
# 258199: games 146, reward -11.090, eps 0.01, speed 130.25 f/s
# 260581: games 147, reward -10.730, eps 0.01, speed 129.47 f/s
# 263687: games 148, reward -10.390, eps 0.01, speed 131.21 f/s
# 266403: games 149, reward -10.050, eps 0.01, speed 130.33 f/s
# 268635: games 150, reward -9.710, eps 0.01, speed 131.08 f/s
# 271143: games 151, reward -9.400, eps 0.01, speed 129.62 f/s
# 273419: games 152, reward -9.060, eps 0.01, speed 128.73 f/s
# 275384: games 153, reward -8.670, eps 0.01, speed 128.01 f/s
# 277808: games 154, reward -8.380, eps 0.01, speed 127.64 f/s
# 279812: games 155, reward -8.020, eps 0.01, speed 128.37 f/s
# 281752: games 156, reward -7.650, eps 0.01, speed 130.31 f/s
# 283637: games 157, reward -7.260, eps 0.01, speed 129.35 f/s
# 285883: games 158, reward -6.920, eps 0.01, speed 130.00 f/s
# 287978: games 159, reward -6.570, eps 0.01, speed 129.49 f/s
# 289776: games 160, reward -6.190, eps 0.01, speed 130.73 f/s
# 291437: games 161, reward -5.790, eps 0.01, speed 129.60 f/s
# 293205: games 162, reward -5.390, eps 0.01, speed 128.77 f/s
# 295128: games 163, reward -5.040, eps 0.01, speed 129.52 f/s
# 297039: games 164, reward -4.660, eps 0.01, speed 130.54 f/s
# 298842: games 165, reward -4.280, eps 0.01, speed 129.35 f/s
# 300520: games 166, reward -3.870, eps 0.01, speed 128.94 f/s
# 302374: games 167, reward -3.490, eps 0.01, speed 129.57 f/s
# 304228: games 168, reward -3.160, eps 0.01, speed 129.43 f/s
# 306252: games 169, reward -2.800, eps 0.01, speed 129.79 f/s
# 308073: games 170, reward -2.470, eps 0.01, speed 127.04 f/s
# 309794: games 171, reward -2.080, eps 0.01, speed 130.69 f/s
# 311460: games 172, reward -1.700, eps 0.01, speed 129.62 f/s
# 313261: games 173, reward -1.310, eps 0.01, speed 128.49 f/s
# 315080: games 174, reward -0.930, eps 0.01, speed 129.90 f/s
# 317150: games 175, reward -0.610, eps 0.01, speed 128.99 f/s
# 318911: games 176, reward -0.220, eps 0.01, speed 129.71 f/s
# 320732: games 177, reward 0.180, eps 0.01, speed 128.63 f/s
# 322562: games 178, reward 0.560, eps 0.01, speed 130.23 f/s
# 324332: games 179, reward 0.940, eps 0.01, speed 129.51 f/s
# 326053: games 180, reward 1.340, eps 0.01, speed 130.33 f/s
# 327848: games 181, reward 1.720, eps 0.01, speed 130.89 f/s
# 329808: games 182, reward 2.080, eps 0.01, speed 130.24 f/s
# 332217: games 183, reward 2.300, eps 0.01, speed 129.18 f/s
# 333957: games 184, reward 2.700, eps 0.01, speed 128.85 f/s
# 335781: games 185, reward 3.050, eps 0.01, speed 128.73 f/s
# 337585: games 186, reward 3.430, eps 0.01, speed 127.02 f/s
# 339270: games 187, reward 3.800, eps 0.01, speed 126.70 f/s
# 340987: games 188, reward 4.170, eps 0.01, speed 128.95 f/s
# 342766: games 189, reward 4.530, eps 0.01, speed 128.80 f/s
# 344480: games 190, reward 4.870, eps 0.01, speed 128.26 f/s
# 346242: games 191, reward 5.240, eps 0.01, speed 127.78 f/s
# 347989: games 192, reward 5.610, eps 0.01, speed 129.57 f/s
# 349733: games 193, reward 5.990, eps 0.01, speed 129.49 f/s
# 351558: games 194, reward 6.340, eps 0.01, speed 128.21 f/s
# 353565: games 195, reward 6.650, eps 0.01, speed 130.21 f/s
# 355532: games 196, reward 7.010, eps 0.01, speed 131.07 f/s
# 357242: games 197, reward 7.390, eps 0.01, speed 129.70 f/s
# 358954: games 198, reward 7.750, eps 0.01, speed 129.75 f/s
# 360667: games 199, reward 8.110, eps 0.01, speed 129.28 f/s
# 362614: games 200, reward 8.470, eps 0.01, speed 129.94 f/s
# 364403: games 201, reward 8.830, eps 0.01, speed 129.83 f/s
# 366069: games 202, reward 9.200, eps 0.01, speed 129.31 f/s
# 367731: games 203, reward 9.560, eps 0.01, speed 130.13 f/s
# 369444: games 204, reward 9.880, eps 0.01, speed 129.37 f/s
# 371157: games 205, reward 10.200, eps 0.01, speed 129.04 f/s
# 372926: games 206, reward 10.570, eps 0.01, speed 130.33 f/s
# 374763: games 207, reward 10.860, eps 0.01, speed 129.31 f/s
# 376599: games 208, reward 11.210, eps 0.01, speed 131.52 f/s
# 378708: games 209, reward 11.550, eps 0.01, speed 130.65 f/s
# 380450: games 210, reward 11.840, eps 0.01, speed 128.66 f/s
# 382111: games 211, reward 12.180, eps 0.01, speed 130.01 f/s
# 383808: games 212, reward 12.470, eps 0.01, speed 130.93 f/s
# 385711: games 213, reward 12.740, eps 0.01, speed 130.78 f/s
# 387421: games 214, reward 13.000, eps 0.01, speed 129.65 f/s
# 389441: games 215, reward 13.180, eps 0.01, speed 127.97 f/s
# 391518: games 216, reward 13.320, eps 0.01, speed 127.49 f/s
# 393246: games 217, reward 13.610, eps 0.01, speed 130.04 f/s
# 394876: games 218, reward 13.810, eps 0.01, speed 128.82 f/s
# 396606: games 219, reward 14.080, eps 0.01, speed 129.61 f/s
# 398236: games 220, reward 14.390, eps 0.01, speed 128.87 f/s
# 399897: games 221, reward 14.630, eps 0.01, speed 128.62 f/s
# 401611: games 222, reward 14.860, eps 0.01, speed 127.68 f/s
# 403289: games 223, reward 15.030, eps 0.01, speed 128.23 f/s
# 405072: games 224, reward 15.230, eps 0.01, speed 127.58 f/s
# 406856: games 225, reward 15.400, eps 0.01, speed 129.64 f/s
# 408578: games 226, reward 15.610, eps 0.01, speed 128.95 f/s
# 410307: games 227, reward 15.790, eps 0.01, speed 127.78 f/s
# 412020: games 228, reward 16.050, eps 0.01, speed 128.51 f/s
# 413815: games 229, reward 16.280, eps 0.01, speed 130.08 f/s
# 415741: games 230, reward 16.460, eps 0.01, speed 128.89 f/s
# 417376: games 231, reward 16.720, eps 0.01, speed 131.33 f/s
# 419205: games 232, reward 16.860, eps 0.01, speed 129.94 f/s
# 420935: games 233, reward 17.010, eps 0.01, speed 129.67 f/s
# 423018: games 234, reward 17.190, eps 0.01, speed 129.45 f/s
# 424648: games 235, reward 17.330, eps 0.01, speed 128.21 f/s
# 426337: games 236, reward 17.540, eps 0.01, speed 128.75 f/s
# 427967: games 237, reward 17.670, eps 0.01, speed 131.06 f/s
# 429599: games 238, reward 17.860, eps 0.01, speed 128.19 f/s
# 431231: games 239, reward 18.020, eps 0.01, speed 129.66 f/s
# 432863: games 240, reward 18.200, eps 0.01, speed 129.72 f/s
# 434494: games 241, reward 18.240, eps 0.01, speed 127.99 f/s
# 436124: games 242, reward 18.330, eps 0.01, speed 129.30 f/s
# 437932: games 243, reward 18.360, eps 0.01, speed 128.63 f/s
# 439865: games 244, reward 18.410, eps 0.01, speed 128.12 f/s
# 441600: games 245, reward 18.420, eps 0.01, speed 129.01 f/s
# 443283: games 246, reward 18.470, eps 0.01, speed 128.43 f/s
# 445328: games 247, reward 18.480, eps 0.01, speed 128.51 f/s
# 447040: games 248, reward 18.540, eps 0.01, speed 127.45 f/s
# 448675: games 249, reward 18.610, eps 0.01, speed 127.37 f/s
# 450309: games 250, reward 18.680, eps 0.01, speed 129.17 f/s
# 452000: games 251, reward 18.760, eps 0.01, speed 128.49 f/s
# 453633: games 252, reward 18.830, eps 0.01, speed 129.01 f/s
# 455459: games 253, reward 18.820, eps 0.01, speed 127.87 f/s
# 457192: games 254, reward 18.910, eps 0.01, speed 128.51 f/s
# 458826: games 255, reward 18.960, eps 0.01, speed 129.61 f/s
# 460461: games 256, reward 18.990, eps 0.01, speed 130.53 f/s
# 462096: games 257, reward 19.000, eps 0.01, speed 129.42 f/s
# 463985: games 258, reward 19.040, eps 0.01, speed 128.60 f/s
# Solved!

# %%
# === RECORD VIDEO ===
from gymnasium.wrappers import RecordVideo
import glob
from IPython.display import Video, display

VIDEO_PATH = "my_runs/video"
MODEL_PATH = sorted(glob.glob("my_runs/*.dat"))[-1]

env = make_env(DEFAULT_ENV_NAME, render_mode="rgb_array")
env = RecordVideo(env, video_folder=VIDEO_PATH, episode_trigger=lambda x: True)

net = DuelingDQN(env.observation_space.shape, env.action_space.n).to(device)
net.load_state_dict(torch.load(MODEL_PATH, map_location=device))

state, _ = env.reset()
total_reward = 0.0

while True:
    state_v = torch.tensor(np.expand_dims(state, 0)).to(device)
    q_vals = net(state_v)
    action = torch.argmax(q_vals).item()
    state, reward, done, trunc, _ = env.step(action)
    total_reward += reward
    if done or trunc:
        break

env.close()
print(f"Total reward: {total_reward}")

video_file = glob.glob(f"{VIDEO_PATH}/*.mp4")[0]
display(Video(video_file, embed=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /content/my_runs/video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/moviepy/config_defaults.py:1: DeprecationWarning: invalid escape sequence '\P'
#   """
# Moviepy - Building video /content/my_runs/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/my_runs/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/my_runs/video/rl-video-episode-0.mp4
# Total reward: 19.0
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# === Wykresy z TensorBoard ===
from tensorboard.backend.event_processing import event_accumulator

log_dir = writer.log_dir if hasattr(writer, 'log_dir') else "my_runs"
event_files = []
for root, dirs, files in os.walk(log_dir):
    for file in files:
        if file.startswith("events.out.tfevents"):
            event_files.append(os.path.join(root, file))

if event_files:
    ea = event_accumulator.EventAccumulator(event_files[0])
    ea.Reload()

    for tag, title, fname in [
        ("reward", "Nagroda", "reward_plot.png"),
        ("reward_100", "Średnia nagroda (100 gier)", "reward_100_plot.png"),
        ("speed", "Prędkość (kl/s)", "speed_plot.png"),
        ("epsilon", "Epsilon", "epsilon_plot.png")
    ]:
        try:
            scalars = ea.Scalars(tag)
            steps = [s.step for s in scalars]
            values = [s.value for s in scalars]
            plt.figure(figsize=(10, 5))
            plt.plot(steps, values)
            plt.xlabel("Iteracja")
            plt.ylabel(title)
            plt.title(f"Trening – {title}")
            plt.grid()
            plt.tight_layout()
            plt.savefig(fname)
            plt.close()
        except KeyError:
            print(f"⚠️ Brak danych dla tagu: {tag}")
else:
    print("⚠️ Nie znaleziono plików TensorBoard.")
