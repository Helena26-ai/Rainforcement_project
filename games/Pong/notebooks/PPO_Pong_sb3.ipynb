# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.atari_wrappers import AtariWrapper

from stable_baselines3.common.utils import get_schedule_fn

import numpy as np
import matplotlib.pyplot as plt
import json

# Callback do logowania i wczesnego zatrzymania
class RewardLoggerCallback(BaseCallback):
    def __init__(self, check_freq=50, target_avg_reward=19.5):
        super().__init__()
        self.episode_rewards = []
        self.check_freq = check_freq
        self.target_avg_reward = target_avg_reward

    def _on_step(self) -> bool:
        infos = self.locals.get("infos", [])
        for info in infos:
            if "episode" in info:
                reward = info["episode"]["r"]
                self.episode_rewards.append(reward)

                if len(self.episode_rewards) >= self.check_freq:
                    recent_avg = np.mean(self.episode_rewards[-self.check_freq:])
                    print(f"[INFO] Średnia z ostatnich {self.check_freq} epizodów: {recent_avg:.2f}")
                    if recent_avg >= self.target_avg_reward:
                        print("Wczesne zatrzymanie")
                        self.model.save("ppo_pong_model_early_stop")
                        with open("pong_rewards_early_stop.json", "w") as f:
                            json.dump(self.episode_rewards, f)
                        self.model.stop_training = True
        return True

# Hiperparametry
learning_rate = get_schedule_fn(2.5e-4)
clip_range = get_schedule_fn(0.1)
n_envs = 8
n_steps = 128
batch_size = 256
n_epochs = 4
ent_coef = 0.01
vf_coef = 0.5
frame_stack = 4
total_timesteps = int(10_000_000)

env_id = "PongNoFrameskip-v4"
vec_env = make_atari_env(env_id, n_envs=n_envs, seed=0)
vec_env = VecFrameStack(vec_env, n_stack=frame_stack)

# Parametry polityki
policy_kwargs = dict(ortho_init=False)

# Tworzenie modelu
model = PPO(
    policy="CnnPolicy",
    env=vec_env,
    learning_rate=learning_rate,
    clip_range=clip_range,
    n_steps=n_steps,
    batch_size=batch_size,
    n_epochs=n_epochs,
    ent_coef=ent_coef,
    vf_coef=vf_coef,
    policy_kwargs=policy_kwargs,
    verbose=1
)

reward_callback = RewardLoggerCallback(check_freq=50, target_avg_reward=19.5)

# Trening
model.learn(total_timesteps=total_timesteps, callback=reward_callback)

# Zapis modelu i nagród
model.save("ppo_pong_model")

with open("pong_rewards.json", "w") as f:
    json.dump(reward_callback.episode_rewards, f)
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.00133     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0416      |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 0.128       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -20.6        |
# | time/                   |              |
# |    fps                  | 109          |
# |    iterations           | 19           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0021789335 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.00261      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0297       |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 0.0978       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | -20.6       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 20          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.002827754 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.00724     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0306      |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.000593   |
# |    value_loss           | 0.12        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -20.6        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 21           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0029975327 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.00446      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0437       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 0.126        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.52e+03     |
# |    ep_rew_mean          | -20.6        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 22           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0020638437 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.00299      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0293       |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00072     |
# |    value_loss           | 0.0921       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.52e+03     |
# |    ep_rew_mean          | -20.5        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 23           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0038460165 |
# |    clip_fraction        | 0.161        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.0022       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0469       |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 0.15         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.52e+03     |
# |    ep_rew_mean          | -20.5        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 24           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0016009733 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.00191      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0282       |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 0.116        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+03      |
# |    ep_rew_mean          | -20.6        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 25           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0041197645 |
# |    clip_fraction        | 0.0872       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.00171      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0339       |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.000594    |
# |    value_loss           | 0.124        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+03      |
# |    ep_rew_mean          | -20.6        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 26           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0025265652 |
# |    clip_fraction        | 0.0522       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.00524      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0346       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00033      |
# |    value_loss           | 0.106        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.49e+03     |
# |    ep_rew_mean          | -20.5        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 27           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0034920187 |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.00503      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0404       |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 0.109        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.48e+03    |
# |    ep_rew_mean          | -20.6       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 28          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.003033677 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.000691    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0541      |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00039    |
# |    value_loss           | 0.152       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.48e+03     |
# |    ep_rew_mean          | -20.5        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 29           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0034339183 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.00198      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0464       |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 0.119        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+03      |
# |    ep_rew_mean          | -20.5        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 30           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0037264312 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.00598      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0308       |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 0.108        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+03     |
# |    ep_rew_mean          | -20.5       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 31          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.003300449 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.000138    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0626      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00153    |
# |    value_loss           | 0.164       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.5e+03      |
# |    ep_rew_mean          | -20.5        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 32           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0032457048 |
# |    clip_fraction        | 0.0693       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.000781     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0534       |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 0.114        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.51e+03    |
# |    ep_rew_mean          | -20.5       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 33          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.004348712 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.0021      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0376      |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 0.135       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.51e+03    |
# |    ep_rew_mean          | -20.5       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 34          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002574698 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.00289     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.051       |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 0.119       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.52e+03    |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 35          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.003259895 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | -0.0014     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0531      |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 0.129       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.52e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 36           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0041451943 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | 0.00515      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0325       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 0.126        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.52e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 37           |
# |    time_elapsed         | 351          |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0042379354 |
# |    clip_fraction        | 0.217        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.00249      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0253       |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 0.0978       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.52e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 38           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0032359757 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.00404      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.045        |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 0.114        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.52e+03    |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 39          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.000848975 |
# |    clip_fraction        | 0.0144      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.00421     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0342      |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -2.13e-05   |
# |    value_loss           | 0.0962      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.52e+03    |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 40          |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002087712 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.00779     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0316      |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.000727   |
# |    value_loss           | 0.111       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.52e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 41           |
# |    time_elapsed         | 390          |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0011121513 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.000887     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0543       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000417    |
# |    value_loss           | 0.13         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.51e+03    |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 42          |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.002953523 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.00202     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0391      |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 0.12        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.52e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 43           |
# |    time_elapsed         | 409          |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0031780903 |
# |    clip_fraction        | 0.0823       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.0101       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0317       |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 0.105        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 44          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.003110858 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.0093      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0341      |
# |    n_updates            | 172         |
# |    policy_gradient_loss | 1.51e-05    |
# |    value_loss           | 0.113       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 45          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.003120978 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.00401     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.049       |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 0.121       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 46           |
# |    time_elapsed         | 439          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0018019562 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.00237      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.027        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000515    |
# |    value_loss           | 0.0946       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.40
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.58e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 47           |
# |    time_elapsed         | 449          |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0015216614 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.00388      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0506       |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00071     |
# |    value_loss           | 0.112        |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.40
# [INFO] Średnia z ostatnich 50 epizodów: -20.40
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 48           |
# |    time_elapsed         | 459          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0031206585 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.0054       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0243       |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 0.106        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.56e+03    |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 49          |
# |    time_elapsed         | 469         |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.004787093 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.00583     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.05        |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 0.131       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.56e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 50           |
# |    time_elapsed         | 479          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0037170905 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.00338      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0356       |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 0.0957       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.42
# [INFO] Średnia z ostatnich 50 epizodów: -20.40
# [INFO] Średnia z ostatnich 50 epizodów: -20.42
# [INFO] Średnia z ostatnich 50 epizodów: -20.42
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.58e+03    |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 51          |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.004751825 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.00243     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0586      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 0.135       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.58e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 52           |
# |    time_elapsed         | 498          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0024193712 |
# |    clip_fraction        | 0.0872       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.00848      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0521       |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 0.141        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.58e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 53           |
# |    time_elapsed         | 508          |
# |    total_timesteps      | 54272        |
# | train/                  |              |
# |    approx_kl            | 0.0012418518 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.00166      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0255       |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.000297    |
# |    value_loss           | 0.0942       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.42
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.59e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 54           |
# |    time_elapsed         | 518          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0024267505 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.00274      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0399       |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 0.1          |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.40
# [INFO] Średnia z ostatnich 50 epizodów: -20.40
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.59e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 55           |
# |    time_elapsed         | 528          |
# |    total_timesteps      | 56320        |
# | train/                  |              |
# |    approx_kl            | 0.0016695126 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.00756      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.038        |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.00087     |
# |    value_loss           | 0.113        |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.36
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 56           |
# |    time_elapsed         | 537          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0027201045 |
# |    clip_fraction        | 0.0537       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.0091       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0488       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 0.113        |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.36
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.59e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 57           |
# |    time_elapsed         | 546          |
# |    total_timesteps      | 58368        |
# | train/                  |              |
# |    approx_kl            | 0.0039878706 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.00369      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0507       |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 0.134        |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.36
# [INFO] Średnia z ostatnich 50 epizodów: -20.38
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.59e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 58           |
# |    time_elapsed         | 556          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0024913722 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.00902      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0268       |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 0.111        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.59e+03    |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 59          |
# |    time_elapsed         | 567         |
# |    total_timesteps      | 60416       |
# | train/                  |             |
# |    approx_kl            | 0.001815412 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.00735     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0463      |
# |    n_updates            | 232         |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 0.136       |
# -----------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.34
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 60           |
# |    time_elapsed         | 576          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0011311442 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.00184      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0474       |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.000423    |
# |    value_loss           | 0.13         |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.36
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 61           |
# |    time_elapsed         | 585          |
# |    total_timesteps      | 62464        |
# | train/                  |              |
# |    approx_kl            | 0.0020954104 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.00995      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.031        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 7.43e-05     |
# |    value_loss           | 0.108        |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.36
# [INFO] Średnia z ostatnich 50 epizodów: -20.32
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 62           |
# |    time_elapsed         | 595          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0027155292 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.00758      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0421       |
# |    n_updates            | 244          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 0.107        |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.30
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.61e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 63           |
# |    time_elapsed         | 605          |
# |    total_timesteps      | 64512        |
# | train/                  |              |
# |    approx_kl            | 0.0025803363 |
# |    clip_fraction        | 0.0928       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.0085       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.048        |
# |    n_updates            | 248          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 0.133        |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.30
# [INFO] Średnia z ostatnich 50 epizodów: -20.30
# [INFO] Średnia z ostatnich 50 epizodów: -20.30
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 64           |
# |    time_elapsed         | 615          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0022594312 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.0102       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0334       |
# |    n_updates            | 252          |
# |    policy_gradient_loss | -0.00093     |
# |    value_loss           | 0.107        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.6e+03     |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 65          |
# |    time_elapsed         | 625         |
# |    total_timesteps      | 66560       |
# | train/                  |             |
# |    approx_kl            | 0.002496333 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.00725     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0503      |
# |    n_updates            | 256         |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 0.149       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 66           |
# |    time_elapsed         | 635          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0033100392 |
# |    clip_fraction        | 0.117        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.64        |
# |    explained_variance   | 0.00428      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0339       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 0.111        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.6e+03     |
# |    ep_rew_mean          | -20.4       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 67          |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 68608       |
# | train/                  |             |
# |    approx_kl            | 0.003548079 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.00738     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0306      |
# |    n_updates            | 264         |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 0.119       |
# -----------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.28
# [INFO] Średnia z ostatnich 50 epizodów: -20.28
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.6e+03    |
# |    ep_rew_mean          | -20.4      |
# | time/                   |            |
# |    fps                  | 106        |
# |    iterations           | 68         |
# |    time_elapsed         | 655        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00277123 |
# |    clip_fraction        | 0.051      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | 0.0112     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0195     |
# |    n_updates            | 268        |
# |    policy_gradient_loss | -0.0015    |
# |    value_loss           | 0.0908     |
# ----------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.32
# [INFO] Średnia z ostatnich 50 epizodów: -20.32
# [INFO] Średnia z ostatnich 50 epizodów: -20.30
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.59e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 69           |
# |    time_elapsed         | 664          |
# |    total_timesteps      | 70656        |
# | train/                  |              |
# |    approx_kl            | 0.0011529977 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.0164       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0372       |
# |    n_updates            | 272          |
# |    policy_gradient_loss | 0.000457     |
# |    value_loss           | 0.125        |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.34
# [INFO] Średnia z ostatnich 50 epizodów: -20.34
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.59e+03     |
# |    ep_rew_mean          | -20.4        |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 70           |
# |    time_elapsed         | 674          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0019041579 |
# |    clip_fraction        | 0            |
# ...
# [INFO] Średnia z ostatnich 50 epizodów: -20.14
# [INFO] Średnia z ostatnich 50 epizodów: -20.14
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.65e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 232          |
# |    time_elapsed         | 2270         |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0006927887 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.729        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0313       |
# |    n_updates            | 924          |
# |    policy_gradient_loss | -0.000438    |
# |    value_loss           | 0.093        |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.12
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.66e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 233          |
# |    time_elapsed         | 2279         |
# |    total_timesteps      | 238592       |
# | train/                  |              |
# |    approx_kl            | 0.0037149503 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.000319     |
# |    n_updates            | 928          |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 0.0537       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.14
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.65e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 234          |
# |    time_elapsed         | 2289         |
# |    total_timesteps      | 239616       |
# | train/                  |              |
# |    approx_kl            | 0.0026046683 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.000991     |
# |    n_updates            | 932          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 0.054        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.65e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 235          |
# |    time_elapsed         | 2299         |
# |    total_timesteps      | 240640       |
# | train/                  |              |
# |    approx_kl            | 0.0029041278 |
# |    clip_fraction        | 0.0994       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.512        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0191       |
# |    n_updates            | 936          |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 0.0881       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.12
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.66e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 236          |
# |    time_elapsed         | 2309         |
# |    total_timesteps      | 241664       |
# | train/                  |              |
# |    approx_kl            | 0.0037674317 |
# |    clip_fraction        | 0.0957       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.576        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0258       |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 0.08         |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.16
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.66e+03     |
# |    ep_rew_mean          | -20.2        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 237          |
# |    time_elapsed         | 2319         |
# |    total_timesteps      | 242688       |
# | train/                  |              |
# |    approx_kl            | 0.0025589862 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0295       |
# |    n_updates            | 944          |
# |    policy_gradient_loss | -0.000972    |
# |    value_loss           | 0.0998       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.66e+03     |
# |    ep_rew_mean          | -20.2        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 238          |
# |    time_elapsed         | 2329         |
# |    total_timesteps      | 243712       |
# | train/                  |              |
# |    approx_kl            | 0.0016369658 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0254       |
# |    n_updates            | 948          |
# |    policy_gradient_loss | -0.000504    |
# |    value_loss           | 0.0829       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.18
# [INFO] Średnia z ostatnich 50 epizodów: -20.18
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.65e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 239          |
# |    time_elapsed         | 2339         |
# |    total_timesteps      | 244736       |
# | train/                  |              |
# |    approx_kl            | 0.0018636171 |
# |    clip_fraction        | 0.0955       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.372        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0162       |
# |    n_updates            | 952          |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 0.0797       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.16
# [INFO] Średnia z ostatnich 50 epizodów: -20.18
# [INFO] Średnia z ostatnich 50 epizodów: -20.16
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.67e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 240          |
# |    time_elapsed         | 2349         |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0004888751 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.798        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00731      |
# |    n_updates            | 956          |
# |    policy_gradient_loss | -0.000348    |
# |    value_loss           | 0.0675       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.67e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 241          |
# |    time_elapsed         | 2359         |
# |    total_timesteps      | 246784       |
# | train/                  |              |
# |    approx_kl            | 0.0017603803 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.657        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0132       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 0.0732       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.14
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.68e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 242          |
# |    time_elapsed         | 2368         |
# |    total_timesteps      | 247808       |
# | train/                  |              |
# |    approx_kl            | 0.0034112744 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.292        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0225       |
# |    n_updates            | 964          |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 0.0853       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.18
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.67e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 243          |
# |    time_elapsed         | 2378         |
# |    total_timesteps      | 248832       |
# | train/                  |              |
# |    approx_kl            | 0.0020307943 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00115      |
# |    n_updates            | 968          |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 0.0537       |
# ------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.16
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.68e+03      |
# |    ep_rew_mean          | -20.3         |
# | time/                   |               |
# |    fps                  | 104           |
# |    iterations           | 244           |
# |    time_elapsed         | 2388          |
# |    total_timesteps      | 249856        |
# | train/                  |               |
# |    approx_kl            | 0.00050763873 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | -1.73         |
# |    explained_variance   | 0.762         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -8.33e-06     |
# |    n_updates            | 972           |
# |    policy_gradient_loss | -0.000164     |
# |    value_loss           | 0.0421        |
# -------------------------------------------
# [INFO] Średnia z ostatnich 50 epizodów: -20.18
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.68e+03     |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 245          |
# |    time_elapsed         | 2398         |
# |    total_timesteps      | 250880       |
# | train/                  |              |
# |    approx_kl            | 0.0009323946 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.565        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0105       |
# |    n_updates            | 976          |
# |    policy_gradient_loss | -0.000768    |
# |    value_loss           | 0.0663       |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7ff78c8f93b7> in <cell line: 0>()
#      76
#      77 # Trening
# ---> 78 model.learn(total_timesteps=total_timesteps, callback=reward_callback)
#      79
#      80 # Zapis modelu i nagród
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309         progress_bar: bool = False,
#     310     ) -> SelfPPO:
# --> 311         return super().learn(
#     312             total_timesteps=total_timesteps,
#     313             callback=callback,
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     335                 self.dump_logs(iteration)
#     336
# --> 337             self.train()
#     338
#     339         callback.on_training_end()
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/ppo/ppo.py in train(self)
#     273                 # Optimization step
#     274                 self.policy.optimizer.zero_grad()
# --> 275                 loss.backward()
#     276                 # Clip grad norm
#     277                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     821         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822     try:
# --> 823         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824             t_outputs, *args, **kwargs
#     825         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:
