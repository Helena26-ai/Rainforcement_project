# %% [markdown]
# <a href="https://colab.research.google.com/github/Helena26-ai/Rainforcement_project/blob/Helena/Pong_DQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium[atari,accept-rom-license]==0.29.1
# Out:
# Collecting gymnasium==0.29.1 (from gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->gymnasium[accept-rom-license,atari]==0.29.1) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->gymnasium[accept-rom-license,atari]==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->gymnasium[accept-rom-license,atari]==0.29.1) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.29.1->gymnasium[accept-rom-license,atari]==0.29.1) (0.0.4)
# Collecting autorom~=0.4.2 (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading AutoROM-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting shimmy<1.0,>=0.1.0 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading Shimmy-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (8.1.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (4.67.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 15.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[accept-rom-license,atari]==0.29.1)
#   Downloading ale_py-0.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0; extra == "atari"->gymnasium[accept-rom-license,atari]==0.29.1) (6.5.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.4.2->autorom[accept-rom-license]~=0.4.2; extra == "accept-rom-license"->gymnasium[accept-rom-license,atari]==0.29.1) (2025.4.26)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 58.8 MB/s eta 0:00:00
# Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Downloading ale_py-0.8.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 83.6 MB/s eta 0:00:00
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446710 sha256=5404f9fda4289ec66c251f0722836d231013ad87a12528499295f8fff393fed0
#   Stored in directory: /root/.cache/pip/wheels/bc/fc/c6/8aa657c0d2089982f2dabd110efc68c61eb49831fdb7397351
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: gymnasium, ale-py, shimmy, AutoROM.accept-rom-license, autorom
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.1.1
#     Uninstalling gymnasium-1.1.1:
#       Successfully uninstalled gymnasium-1.1.1
#   Attempting uninstall: ale-py
#     Found existing installation: ale-py 0.11.0
#     Uninstalling ale-py-0.11.0:
#       Successfully uninstalled ale-py-0.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires ale-py>=0.10.1, but you have ale-py 0.8.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.4.2 gymnasium-0.29.1 shimmy-0.2.1

# %%
from gymnasium.envs import registry
print([env for env in registry.keys() if "Pong" in env])
# Out:
# ['Pong-v0', 'PongDeterministic-v0', 'PongNoFrameskip-v0', 'Pong-v4', 'PongDeterministic-v4', 'PongNoFrameskip-v4', 'Pong-ram-v0', 'Pong-ramDeterministic-v0', 'Pong-ramNoFrameskip-v0', 'Pong-ram-v4', 'Pong-ramDeterministic-v4', 'Pong-ramNoFrameskip-v4', 'ALE/Pong-v5', 'ALE/Pong-ram-v5']

# %%
# !pip install stable-baselines3 tensorboard matplotlib -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.1 MB/s eta 0:00:00

# %%
import os
#import ale_py
import gymnasium as gym
from gymnasium import spaces
import collections
import typing as tt
import numpy as np
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard.writer import SummaryWriter
from gymnasium.wrappers import RecordVideo
import matplotlib.pyplot as plt
from stable_baselines3.common.atari_wrappers import AtariWrapper
from dataclasses import dataclass
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b0d5b29e18d9> in <cell line: 0>()
#      13 from gymnasium.wrappers import RecordVideo
#      14 import matplotlib.pyplot as plt
# ---> 15 from stable_baselines3.common.atari_wrappers import AtariWrapper
#      16 from dataclasses import dataclass
#
# ModuleNotFoundError: No module named 'stable_baselines3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
os.makedirs("my_runs", exist_ok=True)
os.makedirs("my_runs/video", exist_ok=True)

# %%
# DQN
class DQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(DQN, self).__init__()
        self.conv = nn.Sequential( #analiza klatki z gry, wybór cech
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4), #filtr o wym. 8x8
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
        )
        conv_out_size = self.conv(torch.zeros(1, *input_shape)).shape[1]
        self.fc = nn.Sequential(
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions) #zwraca wartości f. Q dla każdej z 6 akcji, wybiera akcję o największej wartości Q
        )

    def forward(self, x): #normalizacja danych i przepuszczenie przez sieć
        return self.fc(self.conv(x.float() / 255))

# %%
class ImageToPyTorch(gym.ObservationWrapper): # zamina kolejności parametrów (wysokość, szerokość, kanał)->(kanał, wysokość, szerokość)
    def __init__(self, env):
        super().__init__(env)
        obs = self.observation_space
        self.observation_space = spaces.Box(
            low=obs.low.min(), high=obs.high.max(),
            shape=(obs.shape[2], obs.shape[0], obs.shape[1]), dtype=obs.dtype)

    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)

class BufferWrapper(gym.ObservationWrapper): #bufor do przechowywania kilku ostatnich klatek(4), łączy je w jedną obserwację (state)
    def __init__(self, env, n_steps):
        super().__init__(env)
        self.buffer = collections.deque(maxlen=n_steps)
        obs = env.observation_space
        self.observation_space = spaces.Box(
            low=np.repeat(obs.low, n_steps, axis=0),
            high=np.repeat(obs.high, n_steps, axis=0),
            dtype=obs.dtype)

    def reset(self, **kwargs): #inicjalizacja
        for _ in range(self.buffer.maxlen - 1):
            self.buffer.append(self.env.observation_space.low)
        obs, info = self.env.reset(**kwargs)
        return self.observation(obs), info

    def observation(self, observation): #dodawanie ramek
        self.buffer.append(observation)
        return np.concatenate(self.buffer)

def make_env(env_name: str, **kwargs):
    env = gym.make(env_name, **kwargs)
    env = AtariWrapper(env, clip_reward=False, noop_max=0) #upraszcz i normalizuje środowisko, nie wprowadza losowych początkowych ruchów
    env = ImageToPyTorch(env)
    env = BufferWrapper(env, n_steps=4)
    return env

# %%
DEFAULT_ENV_NAME = "PongNoFrameskip-v4"
MEAN_REWARD_BOUND = 19
GAMMA = 0.99
BATCH_SIZE = 32
REPLAY_SIZE = 10000
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 1000
REPLAY_START_SIZE = 10000
EPSILON_DECAY_LAST_FRAME = 150000
EPSILON_START = 1.0
EPSILON_FINAL = 0.01

@dataclass
class Experience:
    state: np.ndarray
    action: int
    reward: float
    done_trunc: bool
    new_state: np.ndarray

#przechowuje wiele doświadczeń: miesza je w czasie, dzięki temu każde batch treningowe jest różnorodne i mniej skorelowane
#experience replay
class ExperienceBuffer:
    def __init__(self, capacity: int):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience: Experience):
        self.buffer.append(experience)

    def sample(self, batch_size: int) -> list: #losuje 32 doświdczenia (state, action, reward, done, next_state)
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        return [self.buffer[idx] for idx in indices]

class Agent:
    def __init__(self, env: gym.Env, exp_buffer: ExperienceBuffer):
        self.env = env
        self.exp_buffer = exp_buffer
        self.state = None
        self.total_reward = 0.0
        self._reset()

    def _reset(self):
        self.state, _ = self.env.reset()
        self.total_reward = 0.0

    @torch.no_grad()
    def play_step(self, net: DQN, device: torch.device, epsilon=0.0):
        if np.random.random() < epsilon:
            action = self.env.action_space.sample()
        else:
            state_v = torch.tensor(np.array([self.state]), device=device)
            q_vals = net(state_v)
            action = torch.argmax(q_vals).item()

        new_state, reward, done, trunc, _ = self.env.step(action)
        self.total_reward += reward
        self.exp_buffer.append(Experience(self.state, action, reward, done or trunc, new_state))
        self.state = new_state

        if done or trunc:
            r = self.total_reward
            self._reset()
            return r
        return None

def batch_to_tensors(batch, device):
    states = torch.tensor(np.array([e.state for e in batch]), device=device)
    actions = torch.tensor([e.action for e in batch], dtype=torch.long, device=device)
    rewards = torch.tensor([e.reward for e in batch], dtype=torch.float32, device=device)
    dones = torch.tensor([e.done_trunc for e in batch], dtype=torch.bool, device=device)
    next_states = torch.tensor(np.array([e.new_state for e in batch]), device=device)
    return states, actions, rewards, dones, next_states

def calc_loss(batch, net, tgt_net, device):
    states, actions, rewards, dones, next_states = batch_to_tensors(batch, device)
    state_action_values = net(states).gather(1, actions.unsqueeze(-1)).squeeze(-1)
    with torch.no_grad():
        next_state_values = tgt_net(next_states).max(1)[0]
        next_state_values[dones] = 0.0
    expected_values = rewards + GAMMA * next_state_values
    return nn.MSELoss()(state_action_values, expected_values)

# Start training
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
env = make_env(DEFAULT_ENV_NAME)
net = DQN(env.observation_space.shape, env.action_space.n).to(device)
tgt_net = DQN(env.observation_space.shape, env.action_space.n).to(device) #jest aktualizowana rzadziej, jest kopią net, oblicza wartość docelową, zachowuje stabilność
buffer = ExperienceBuffer(REPLAY_SIZE)
agent = Agent(env, buffer)
optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
writer = SummaryWriter(log_dir="my_runs")

epsilon = EPSILON_START
frame_idx = 0
best_mean_reward = None
rewards = []
ts = time.time()
ts_frame = 0

while True:
    frame_idx += 1
    epsilon = max(EPSILON_FINAL, EPSILON_START - frame_idx / EPSILON_DECAY_LAST_FRAME)
    reward = agent.play_step(net, device, epsilon)
    if reward is not None:
        rewards.append(reward)
        speed = (frame_idx - ts_frame) / (time.time() - ts)
        ts_frame = frame_idx
        ts = time.time()
        m_reward = np.mean(rewards[-100:])
        print(f"{frame_idx}: games {len(rewards)}, reward {m_reward:.3f}, eps {epsilon:.2f}, speed {speed:.2f} f/s")
        writer.add_scalar("epsilon", epsilon, frame_idx)
        writer.add_scalar("speed", speed, frame_idx)
        writer.add_scalar("reward_100", m_reward, frame_idx)
        writer.add_scalar("reward", reward, frame_idx)
        if best_mean_reward is None or best_mean_reward < m_reward:
            torch.save(net.state_dict(), f"my_runs/best_{m_reward:.0f}.dat")
            best_mean_reward = m_reward
        if m_reward > MEAN_REWARD_BOUND:
            print("Solved!")
            break

    if len(buffer) < REPLAY_START_SIZE:
        continue

    if frame_idx % SYNC_TARGET_FRAMES == 0:
        tgt_net.load_state_dict(net.state_dict())

    batch = buffer.sample(BATCH_SIZE)
    optimizer.zero_grad()
    loss = calc_loss(batch, net, tgt_net, device)
    loss.backward()
    optimizer.step()

writer.close()
# Out:
# 822: games 1, reward -21.000, eps 0.99, speed 602.73 f/s
# 1892: games 2, reward -20.000, eps 0.99, speed 877.46 f/s
# 2761: games 3, reward -20.000, eps 0.98, speed 876.55 f/s
# 3523: games 4, reward -20.250, eps 0.98, speed 876.18 f/s
# 4639: games 5, reward -20.000, eps 0.97, speed 900.27 f/s
# 5568: games 6, reward -20.000, eps 0.96, speed 873.61 f/s
# 6470: games 7, reward -20.143, eps 0.96, speed 881.71 f/s
# 7232: games 8, reward -20.250, eps 0.95, speed 875.25 f/s
# 7994: games 9, reward -20.333, eps 0.95, speed 879.72 f/s
# 8862: games 10, reward -20.300, eps 0.94, speed 856.89 f/s
# 9652: games 11, reward -20.364, eps 0.94, speed 864.08 f/s
# 10488: games 12, reward -20.333, eps 0.93, speed 220.41 f/s
# 11408: games 13, reward -20.308, eps 0.92, speed 173.08 f/s
# 12248: games 14, reward -20.357, eps 0.92, speed 172.59 f/s
# 13118: games 15, reward -20.400, eps 0.91, speed 175.75 f/s
# 13998: games 16, reward -20.438, eps 0.91, speed 175.51 f/s
# 14958: games 17, reward -20.412, eps 0.90, speed 174.10 f/s
# 16041: games 18, reward -20.333, eps 0.89, speed 166.54 f/s
# 16863: games 19, reward -20.368, eps 0.89, speed 171.51 f/s
# 17813: games 20, reward -20.300, eps 0.88, speed 173.66 f/s
# 18888: games 21, reward -20.286, eps 0.87, speed 172.67 f/s
# 19979: games 22, reward -20.273, eps 0.87, speed 176.96 f/s
# 20848: games 23, reward -20.304, eps 0.86, speed 172.29 f/s
# 21928: games 24, reward -20.250, eps 0.85, speed 168.88 f/s
# 22847: games 25, reward -20.240, eps 0.85, speed 174.23 f/s
# 23827: games 26, reward -20.231, eps 0.84, speed 172.72 f/s
# 24826: games 27, reward -20.185, eps 0.83, speed 168.91 f/s
# 25783: games 28, reward -20.179, eps 0.83, speed 170.95 f/s
# 26818: games 29, reward -20.207, eps 0.82, speed 170.60 f/s
# 27642: games 30, reward -20.233, eps 0.82, speed 166.21 f/s
# 28695: games 31, reward -20.194, eps 0.81, speed 173.78 f/s
# 29550: games 32, reward -20.188, eps 0.80, speed 165.16 f/s
# 30479: games 33, reward -20.182, eps 0.80, speed 172.64 f/s
# 31578: games 34, reward -20.147, eps 0.79, speed 171.27 f/s
# 32613: games 35, reward -20.114, eps 0.78, speed 175.85 f/s
# 33592: games 36, reward -20.139, eps 0.78, speed 170.81 f/s
# 34614: games 37, reward -20.108, eps 0.77, speed 173.60 f/s
# 35629: games 38, reward -20.132, eps 0.76, speed 169.66 f/s
# 36620: games 39, reward -20.103, eps 0.76, speed 172.42 f/s
# 37662: games 40, reward -20.050, eps 0.75, speed 168.25 f/s
# 38778: games 41, reward -20.024, eps 0.74, speed 173.32 f/s
# 39781: games 42, reward -20.048, eps 0.73, speed 166.54 f/s
# 40955: games 43, reward -20.000, eps 0.73, speed 159.49 f/s
# 42141: games 44, reward -19.955, eps 0.72, speed 168.61 f/s
# 43250: games 45, reward -19.933, eps 0.71, speed 166.99 f/s
# 44379: games 46, reward -19.913, eps 0.70, speed 170.41 f/s
# 45467: games 47, reward -19.936, eps 0.70, speed 163.81 f/s
# 46257: games 48, reward -19.958, eps 0.69, speed 165.58 f/s
# 47404: games 49, reward -19.918, eps 0.68, speed 165.68 f/s
# 48405: games 50, reward -19.900, eps 0.68, speed 172.33 f/s
# 49304: games 51, reward -19.922, eps 0.67, speed 164.60 f/s
# 50321: games 52, reward -19.923, eps 0.66, speed 169.84 f/s
# 51444: games 53, reward -19.906, eps 0.66, speed 166.63 f/s
# 52346: games 54, reward -19.926, eps 0.65, speed 171.01 f/s
# 53412: games 55, reward -19.927, eps 0.64, speed 165.58 f/s
# 54727: games 56, reward -19.893, eps 0.64, speed 169.03 f/s
# 55845: games 57, reward -19.877, eps 0.63, speed 167.69 f/s
# 57106: games 58, reward -19.862, eps 0.62, speed 166.42 f/s
# 58241: games 59, reward -19.864, eps 0.61, speed 165.47 f/s
# 59665: games 60, reward -19.783, eps 0.60, speed 161.45 f/s
# 60917: games 61, reward -19.770, eps 0.59, speed 168.68 f/s
# 62191: games 62, reward -19.758, eps 0.59, speed 164.97 f/s
# 63455: games 63, reward -19.698, eps 0.58, speed 164.23 f/s
# 64573: games 64, reward -19.688, eps 0.57, speed 164.32 f/s
# 65751: games 65, reward -19.662, eps 0.56, speed 167.25 f/s
# 66951: games 66, reward -19.652, eps 0.55, speed 166.04 f/s
# 68339: games 67, reward -19.627, eps 0.54, speed 162.54 f/s
# 69776: games 68, reward -19.618, eps 0.53, speed 164.64 f/s
# 71124: games 69, reward -19.580, eps 0.53, speed 167.26 f/s
# 72286: games 70, reward -19.571, eps 0.52, speed 164.33 f/s
# 73386: games 71, reward -19.577, eps 0.51, speed 162.46 f/s
# 74971: games 72, reward -19.500, eps 0.50, speed 162.93 f/s
# 76530: games 73, reward -19.438, eps 0.49, speed 159.78 f/s
# 77984: games 74, reward -19.405, eps 0.48, speed 155.36 f/s
# 79478: games 75, reward -19.360, eps 0.47, speed 154.85 f/s
# 81462: games 76, reward -19.303, eps 0.46, speed 157.68 f/s
# 83271: games 77, reward -19.247, eps 0.44, speed 162.57 f/s
# 84718: games 78, reward -19.205, eps 0.44, speed 161.50 f/s
# 86340: games 79, reward -19.203, eps 0.42, speed 166.61 f/s
# 87892: games 80, reward -19.163, eps 0.41, speed 163.52 f/s
# 89167: games 81, reward -19.160, eps 0.41, speed 160.21 f/s
# 90558: games 82, reward -19.146, eps 0.40, speed 162.62 f/s
# 92278: games 83, reward -19.133, eps 0.38, speed 164.22 f/s
# 93927: games 84, reward -19.143, eps 0.37, speed 162.81 f/s
# 95344: games 85, reward -19.118, eps 0.36, speed 156.54 f/s
# 96965: games 86, reward -19.081, eps 0.35, speed 158.55 f/s
# 98525: games 87, reward -19.080, eps 0.34, speed 161.42 f/s
# 100037: games 88, reward -19.057, eps 0.33, speed 154.39 f/s
# 101491: games 89, reward -19.056, eps 0.32, speed 159.54 f/s
# 103451: games 90, reward -19.000, eps 0.31, speed 160.82 f/s
# 105263: games 91, reward -18.989, eps 0.30, speed 158.52 f/s
# 107019: games 92, reward -18.967, eps 0.29, speed 155.92 f/s
# 108759: games 93, reward -18.946, eps 0.27, speed 155.89 f/s
# 110718: games 94, reward -18.936, eps 0.26, speed 156.38 f/s
# 112422: games 95, reward -18.947, eps 0.25, speed 157.39 f/s
# 114068: games 96, reward -18.927, eps 0.24, speed 157.59 f/s
# 116104: games 97, reward -18.897, eps 0.23, speed 156.72 f/s
# 117817: games 98, reward -18.898, eps 0.21, speed 156.51 f/s
# 119948: games 99, reward -18.848, eps 0.20, speed 154.49 f/s
# 122194: games 100, reward -18.810, eps 0.19, speed 154.97 f/s
# 124267: games 101, reward -18.750, eps 0.17, speed 152.83 f/s
# 126495: games 102, reward -18.690, eps 0.16, speed 156.15 f/s
# 128359: games 103, reward -18.670, eps 0.14, speed 157.19 f/s
# 130283: games 104, reward -18.620, eps 0.13, speed 155.75 f/s
# 132395: games 105, reward -18.600, eps 0.12, speed 155.95 f/s
# 134086: games 106, reward -18.590, eps 0.11, speed 152.73 f/s
# 136300: games 107, reward -18.540, eps 0.09, speed 155.87 f/s
# 138459: games 108, reward -18.490, eps 0.08, speed 154.11 f/s
# 141613: games 109, reward -18.400, eps 0.06, speed 153.77 f/s
# 143785: games 110, reward -18.320, eps 0.04, speed 155.85 f/s
# 146183: games 111, reward -18.250, eps 0.03, speed 153.24 f/s
# 149127: games 112, reward -18.150, eps 0.01, speed 151.52 f/s
# 151570: games 113, reward -18.060, eps 0.01, speed 152.20 f/s
# 153869: games 114, reward -18.000, eps 0.01, speed 156.04 f/s
# 156782: games 115, reward -17.920, eps 0.01, speed 155.62 f/s
# 159772: games 116, reward -17.860, eps 0.01, speed 150.05 f/s
# 163432: games 117, reward -17.670, eps 0.01, speed 150.65 f/s
# 166939: games 118, reward -17.540, eps 0.01, speed 148.45 f/s
# 169699: games 119, reward -17.420, eps 0.01, speed 152.42 f/s
# 172752: games 120, reward -17.190, eps 0.01, speed 151.38 f/s
# 175454: games 121, reward -17.090, eps 0.01, speed 151.94 f/s
# 178500: games 122, reward -16.930, eps 0.01, speed 153.39 f/s
# 181529: games 123, reward -16.660, eps 0.01, speed 148.13 f/s
# 184673: games 124, reward -16.390, eps 0.01, speed 148.59 f/s
# 187272: games 125, reward -16.080, eps 0.01, speed 151.39 f/s
# 189501: games 126, reward -15.720, eps 0.01, speed 151.81 f/s
# 191597: games 127, reward -15.360, eps 0.01, speed 149.17 f/s
# 193837: games 128, reward -15.000, eps 0.01, speed 153.06 f/s
# 195588: games 129, reward -14.590, eps 0.01, speed 151.21 f/s
# 197666: games 130, reward -14.200, eps 0.01, speed 151.48 f/s
# 199485: games 131, reward -13.820, eps 0.01, speed 151.82 f/s
# 201477: games 132, reward -13.430, eps 0.01, speed 152.50 f/s
# 203237: games 133, reward -13.040, eps 0.01, speed 149.20 f/s
# 205597: games 134, reward -12.710, eps 0.01, speed 149.86 f/s
# 207670: games 135, reward -12.360, eps 0.01, speed 153.81 f/s
# 209591: games 136, reward -11.960, eps 0.01, speed 150.59 f/s
# 211359: games 137, reward -11.570, eps 0.01, speed 150.66 f/s
# 213635: games 138, reward -11.210, eps 0.01, speed 150.48 f/s
# 215460: games 139, reward -10.840, eps 0.01, speed 151.72 f/s
# 217187: games 140, reward -10.460, eps 0.01, speed 153.36 f/s
# 218964: games 141, reward -10.070, eps 0.01, speed 153.13 f/s
# 221007: games 142, reward -9.680, eps 0.01, speed 154.80 f/s
# 222728: games 143, reward -9.300, eps 0.01, speed 151.92 f/s
# 224451: games 144, reward -8.920, eps 0.01, speed 151.75 f/s
# 226398: games 145, reward -8.540, eps 0.01, speed 149.02 f/s
# 228110: games 146, reward -8.140, eps 0.01, speed 152.44 f/s
# 229935: games 147, reward -7.740, eps 0.01, speed 153.11 f/s
# 231677: games 148, reward -7.340, eps 0.01, speed 151.72 f/s
# 233370: games 149, reward -6.950, eps 0.01, speed 149.70 f/s
# 235085: games 150, reward -6.570, eps 0.01, speed 148.70 f/s
# 236746: games 151, reward -6.160, eps 0.01, speed 153.40 f/s
# 239350: games 152, reward -5.890, eps 0.01, speed 153.72 f/s
# 241077: games 153, reward -5.490, eps 0.01, speed 149.76 f/s
# 242934: games 154, reward -5.090, eps 0.01, speed 148.93 f/s
# 244648: games 155, reward -4.680, eps 0.01, speed 151.05 f/s
# 247096: games 156, reward -4.360, eps 0.01, speed 147.46 f/s
# 248879: games 157, reward -3.980, eps 0.01, speed 152.02 f/s
# 250818: games 158, reward -3.610, eps 0.01, speed 152.20 f/s
# 252465: games 159, reward -3.200, eps 0.01, speed 150.30 f/s
# 254379: games 160, reward -2.870, eps 0.01, speed 151.68 f/s
# 256257: games 161, reward -2.500, eps 0.01, speed 152.97 f/s
# 258111: games 162, reward -2.120, eps 0.01, speed 151.23 f/s
# 260389: games 163, reward -1.810, eps 0.01, speed 145.49 f/s
# 262103: games 164, reward -1.420, eps 0.01, speed 152.35 f/s
# 264048: games 165, reward -1.060, eps 0.01, speed 154.30 f/s
# 265803: games 166, reward -0.670, eps 0.01, speed 152.31 f/s
# 267428: games 167, reward -0.280, eps 0.01, speed 150.37 f/s
# 269475: games 168, reward 0.070, eps 0.01, speed 151.12 f/s
# 271236: games 169, reward 0.440, eps 0.01, speed 152.31 f/s
# 272950: games 170, reward 0.830, eps 0.01, speed 153.26 f/s
# 274731: games 171, reward 1.230, eps 0.01, speed 152.20 f/s
# 276420: games 172, reward 1.570, eps 0.01, speed 151.71 f/s
# 278140: games 173, reward 1.920, eps 0.01, speed 151.31 f/s
# 280326: games 174, reward 2.250, eps 0.01, speed 150.25 f/s
# 282106: games 175, reward 2.600, eps 0.01, speed 150.88 f/s
# 283958: games 176, reward 2.920, eps 0.01, speed 151.75 f/s
# 285680: games 177, reward 3.280, eps 0.01, speed 152.97 f/s
# 287638: games 178, reward 3.610, eps 0.01, speed 151.01 f/s
# 289453: games 179, reward 3.990, eps 0.01, speed 154.17 f/s
# 291546: games 180, reward 4.290, eps 0.01, speed 153.11 f/s
# 293371: games 181, reward 4.670, eps 0.01, speed 151.30 f/s
# 295063: games 182, reward 5.050, eps 0.01, speed 152.87 f/s
# 296812: games 183, reward 5.420, eps 0.01, speed 148.91 f/s
# 298565: games 184, reward 5.810, eps 0.01, speed 150.89 f/s
# 300243: games 185, reward 6.180, eps 0.01, speed 154.46 f/s
# 302082: games 186, reward 6.520, eps 0.01, speed 153.25 f/s
# 304019: games 187, reward 6.880, eps 0.01, speed 151.31 f/s
# 306268: games 188, reward 7.200, eps 0.01, speed 146.52 f/s
# 307931: games 189, reward 7.590, eps 0.01, speed 147.89 f/s
# 310024: games 190, reward 7.880, eps 0.01, speed 152.05 f/s
# 311776: games 191, reward 8.240, eps 0.01, speed 153.38 f/s
# 313661: games 192, reward 8.590, eps 0.01, speed 153.66 f/s
# 315473: games 193, reward 8.950, eps 0.01, speed 152.49 f/s
# 317324: games 194, reward 9.310, eps 0.01, speed 153.61 f/s
# 319049: games 195, reward 9.710, eps 0.01, speed 154.55 f/s
# 321006: games 196, reward 10.030, eps 0.01, speed 148.07 f/s
# 322720: games 197, reward 10.390, eps 0.01, speed 153.77 f/s
# 324650: games 198, reward 10.760, eps 0.01, speed 150.97 f/s
# 326504: games 199, reward 11.090, eps 0.01, speed 154.61 f/s
# 328328: games 200, reward 11.430, eps 0.01, speed 153.91 f/s
# 330059: games 201, reward 11.780, eps 0.01, speed 151.61 f/s
# 332228: games 202, reward 12.090, eps 0.01, speed 153.24 f/s
# 333950: games 203, reward 12.470, eps 0.01, speed 153.57 f/s
# 335840: games 204, reward 12.820, eps 0.01, speed 152.14 f/s
# 337579: games 205, reward 13.190, eps 0.01, speed 152.92 f/s
# 339702: games 206, reward 13.570, eps 0.01, speed 153.28 f/s
# 341412: games 207, reward 13.930, eps 0.01, speed 153.14 f/s
# 343306: games 208, reward 14.290, eps 0.01, speed 152.66 f/s
# 345202: games 209, reward 14.600, eps 0.01, speed 151.72 f/s
# 347091: games 210, reward 14.900, eps 0.01, speed 153.30 f/s
# 348782: games 211, reward 15.250, eps 0.01, speed 153.12 f/s
# 350447: games 212, reward 15.560, eps 0.01, speed 152.28 f/s
# 352138: games 213, reward 15.880, eps 0.01, speed 151.47 f/s
# 354218: games 214, reward 16.220, eps 0.01, speed 151.94 f/s
# 355942: games 215, reward 16.550, eps 0.01, speed 148.92 f/s
# 357591: games 216, reward 16.910, eps 0.01, speed 152.80 f/s
# 359699: games 217, reward 17.090, eps 0.01, speed 153.74 f/s
# 361484: games 218, reward 17.340, eps 0.01, speed 154.91 f/s
# 363245: games 219, reward 17.630, eps 0.01, speed 154.53 f/s
# 365074: games 220, reward 17.800, eps 0.01, speed 154.76 f/s
# 366736: games 221, reward 18.100, eps 0.01, speed 153.31 f/s
# 368531: games 222, reward 18.330, eps 0.01, speed 157.03 f/s
# 370365: games 223, reward 18.460, eps 0.01, speed 150.17 f/s
# 372359: games 224, reward 18.560, eps 0.01, speed 152.89 f/s
# 374049: games 225, reward 18.660, eps 0.01, speed 154.92 f/s
# 375739: games 226, reward 18.710, eps 0.01, speed 152.73 f/s
# 377777: games 227, reward 18.700, eps 0.01, speed 153.53 f/s
# 379509: games 228, reward 18.730, eps 0.01, speed 152.79 f/s
# 381259: games 229, reward 18.730, eps 0.01, speed 155.05 f/s
# 383151: games 230, reward 18.720, eps 0.01, speed 151.11 f/s
# 384893: games 231, reward 18.730, eps 0.01, speed 153.84 f/s
# 386861: games 232, reward 18.710, eps 0.01, speed 153.58 f/s
# 388588: games 233, reward 18.710, eps 0.01, speed 151.69 f/s
# 390493: games 234, reward 18.740, eps 0.01, speed 153.07 f/s
# 392154: games 235, reward 18.780, eps 0.01, speed 152.72 f/s
# 393910: games 236, reward 18.780, eps 0.01, speed 147.87 f/s
# 395571: games 237, reward 18.780, eps 0.01, speed 149.51 f/s
# 397349: games 238, reward 18.830, eps 0.01, speed 152.28 f/s
# 399165: games 239, reward 18.850, eps 0.01, speed 154.93 f/s
# 400829: games 240, reward 18.850, eps 0.01, speed 152.27 f/s
# 402600: games 241, reward 18.840, eps 0.01, speed 148.62 f/s
# 404561: games 242, reward 18.840, eps 0.01, speed 153.35 f/s
# 406224: games 243, reward 18.840, eps 0.01, speed 153.70 f/s
# 408067: games 244, reward 18.820, eps 0.01, speed 154.50 f/s
# 409936: games 245, reward 18.800, eps 0.01, speed 154.63 f/s
# 411750: games 246, reward 18.780, eps 0.01, speed 152.48 f/s
# 413520: games 247, reward 18.790, eps 0.01, speed 155.68 f/s
# 415260: games 248, reward 18.800, eps 0.01, speed 153.96 f/s
# 416910: games 249, reward 18.800, eps 0.01, speed 151.25 f/s
# 418559: games 250, reward 18.820, eps 0.01, speed 156.61 f/s
# 420520: games 251, reward 18.800, eps 0.01, speed 154.80 f/s
# 422262: games 252, reward 18.930, eps 0.01, speed 151.19 f/s
# 424338: games 253, reward 18.910, eps 0.01, speed 153.52 f/s
# 426046: games 254, reward 18.930, eps 0.01, speed 152.08 f/s
# 427869: games 255, reward 18.910, eps 0.01, speed 152.84 f/s
# 429703: games 256, reward 18.960, eps 0.01, speed 153.30 f/s
# 431648: games 257, reward 18.950, eps 0.01, speed 153.08 f/s
# 433659: games 258, reward 18.940, eps 0.01, speed 153.88 f/s
# 435881: games 259, reward 18.860, eps 0.01, speed 154.39 f/s
# 437978: games 260, reward 18.850, eps 0.01, speed 151.33 f/s
# 439758: games 261, reward 18.870, eps 0.01, speed 151.96 f/s
# 441949: games 262, reward 18.790, eps 0.01, speed 155.50 f/s
# 443878: games 263, reward 18.830, eps 0.01, speed 153.65 f/s
# 445966: games 264, reward 18.810, eps 0.01, speed 154.90 f/s
# 447800: games 265, reward 18.830, eps 0.01, speed 153.93 f/s
# 449616: games 266, reward 18.820, eps 0.01, speed 154.95 f/s
# 451697: games 267, reward 18.770, eps 0.01, speed 152.67 f/s
# 453480: games 268, reward 18.810, eps 0.01, speed 154.42 f/s
# 455767: games 269, reward 18.740, eps 0.01, speed 152.80 f/s
# 458234: games 270, reward 18.650, eps 0.01, speed 150.01 f/s
# 459995: games 271, reward 18.650, eps 0.01, speed 152.69 f/s
# 462053: games 272, reward 18.620, eps 0.01, speed 152.68 f/s
# 464047: games 273, reward 18.600, eps 0.01, speed 154.04 f/s
# 465886: games 274, reward 18.630, eps 0.01, speed 151.91 f/s
# 467547: games 275, reward 18.640, eps 0.01, speed 151.57 f/s
# 469328: games 276, reward 18.670, eps 0.01, speed 152.18 f/s
# 471046: games 277, reward 18.660, eps 0.01, speed 153.30 f/s
# 473080: games 278, reward 18.660, eps 0.01, speed 150.88 f/s
# 474938: games 279, reward 18.670, eps 0.01, speed 152.96 f/s
# 477297: games 280, reward 18.680, eps 0.01, speed 155.11 f/s
# 479094: games 281, reward 18.680, eps 0.01, speed 154.14 f/s
# 480807: games 282, reward 18.670, eps 0.01, speed 154.84 f/s
# 482455: games 283, reward 18.690, eps 0.01, speed 153.68 f/s
# 484146: games 284, reward 18.710, eps 0.01, speed 156.38 f/s
# 485867: games 285, reward 18.710, eps 0.01, speed 149.60 f/s
# 487684: games 286, reward 18.720, eps 0.01, speed 152.89 f/s
# 489362: games 287, reward 18.750, eps 0.01, speed 154.76 f/s
# 491053: games 288, reward 18.810, eps 0.01, speed 151.64 f/s
# 492898: games 289, reward 18.800, eps 0.01, speed 153.59 f/s
# 494601: games 290, reward 18.860, eps 0.01, speed 156.41 f/s
# 496657: games 291, reward 18.840, eps 0.01, speed 152.83 f/s
# 498305: games 292, reward 18.870, eps 0.01, speed 153.73 f/s
# 500119: games 293, reward 18.870, eps 0.01, speed 153.33 f/s
# 501940: games 294, reward 18.880, eps 0.01, speed 151.10 f/s
# 503858: games 295, reward 18.830, eps 0.01, speed 152.65 f/s
# 505849: games 296, reward 18.870, eps 0.01, speed 155.14 f/s
# 508175: games 297, reward 18.760, eps 0.01, speed 155.20 f/s
# 509952: games 298, reward 18.770, eps 0.01, speed 150.20 f/s
# 512611: games 299, reward 18.680, eps 0.01, speed 152.37 f/s
# 514626: games 300, reward 18.660, eps 0.01, speed 156.45 f/s
# 516716: games 301, reward 18.630, eps 0.01, speed 152.42 f/s
# 518364: games 302, reward 18.660, eps 0.01, speed 150.46 f/s
# 520321: games 303, reward 18.640, eps 0.01, speed 149.23 f/s
# 522123: games 304, reward 18.640, eps 0.01, speed 153.53 f/s
# 524025: games 305, reward 18.640, eps 0.01, speed 151.87 f/s
# 525992: games 306, reward 18.630, eps 0.01, speed 153.37 f/s
# 527846: games 307, reward 18.620, eps 0.01, speed 151.55 f/s
# 529494: games 308, reward 18.630, eps 0.01, speed 155.33 f/s
# 531211: games 309, reward 18.640, eps 0.01, speed 153.87 f/s
# 533147: games 310, reward 18.640, eps 0.01, speed 153.12 f/s
# 534869: games 311, reward 18.630, eps 0.01, speed 152.20 f/s
# 536517: games 312, reward 18.630, eps 0.01, speed 153.01 f/s
# 538165: games 313, reward 18.630, eps 0.01, speed 155.31 f/s
# 539826: games 314, reward 18.640, eps 0.01, speed 151.66 f/s
# 541637: games 315, reward 18.650, eps 0.01, speed 155.79 f/s
# 543285: games 316, reward 18.650, eps 0.01, speed 150.95 f/s
# 545196: games 317, reward 18.660, eps 0.01, speed 154.14 f/s
# 546982: games 318, reward 18.670, eps 0.01, speed 153.16 f/s
# 548630: games 319, reward 18.680, eps 0.01, speed 154.28 f/s
# 550468: games 320, reward 18.650, eps 0.01, speed 153.96 f/s
# 552424: games 321, reward 18.640, eps 0.01, speed 153.82 f/s
# 554291: games 322, reward 18.650, eps 0.01, speed 156.03 f/s
# 556272: games 323, reward 18.650, eps 0.01, speed 155.69 f/s
# 558056: games 324, reward 18.660, eps 0.01, speed 155.19 f/s
# 560084: games 325, reward 18.630, eps 0.01, speed 153.07 f/s
# 562038: games 326, reward 18.590, eps 0.01, speed 150.52 f/s
# 563809: games 327, reward 18.630, eps 0.01, speed 153.63 f/s
# 565553: games 328, reward 18.640, eps 0.01, speed 155.30 f/s
# 567565: games 329, reward 18.630, eps 0.01, speed 154.93 f/s
# 569213: games 330, reward 18.670, eps 0.01, speed 152.67 f/s
# 570904: games 331, reward 18.680, eps 0.01, speed 151.10 f/s
# 572595: games 332, reward 18.720, eps 0.01, speed 151.57 f/s
# 574613: games 333, reward 18.710, eps 0.01, speed 155.70 f/s
# 576546: games 334, reward 18.720, eps 0.01, speed 152.99 f/s
# 578299: games 335, reward 18.730, eps 0.01, speed 152.19 f/s
# 580072: games 336, reward 18.740, eps 0.01, speed 149.94 f/s
# 581733: games 337, reward 18.740, eps 0.01, speed 149.22 f/s
# 583574: games 338, reward 18.730, eps 0.01, speed 149.10 f/s
# 585222: games 339, reward 18.740, eps 0.01, speed 155.91 f/s
# 587069: games 340, reward 18.740, eps 0.01, speed 152.81 f/s
# 589018: games 341, reward 18.740, eps 0.01, speed 155.44 f/s
# 591059: games 342, reward 18.740, eps 0.01, speed 152.67 f/s
# 592773: games 343, reward 18.730, eps 0.01, speed 150.96 f/s
# 594728: games 344, reward 18.730, eps 0.01, speed 148.93 f/s
# 596376: games 345, reward 18.770, eps 0.01, speed 152.81 f/s
# 598067: games 346, reward 18.790, eps 0.01, speed 156.13 f/s
# 600326: games 347, reward 18.730, eps 0.01, speed 154.81 f/s
# 602017: games 348, reward 18.740, eps 0.01, speed 153.31 f/s
# 603731: games 349, reward 18.720, eps 0.01, speed 154.06 f/s
# 605659: games 350, reward 18.700, eps 0.01, speed 154.24 f/s
# 607667: games 351, reward 18.700, eps 0.01, speed 154.61 f/s
# 609626: games 352, reward 18.680, eps 0.01, speed 153.58 f/s
# 611552: games 353, reward 18.680, eps 0.01, speed 157.63 f/s
# 613448: games 354, reward 18.660, eps 0.01, speed 155.92 f/s
# 615409: games 355, reward 18.650, eps 0.01, speed 155.61 f/s
# 617429: games 356, reward 18.630, eps 0.01, speed 156.69 f/s
# 619723: games 357, reward 18.560, eps 0.01, speed 154.08 f/s
# 621525: games 358, reward 18.580, eps 0.01, speed 156.98 f/s
# 623386: games 359, reward 18.640, eps 0.01, speed 155.92 f/s
# 625105: games 360, reward 18.670, eps 0.01, speed 155.79 f/s
# 626880: games 361, reward 18.660, eps 0.01, speed 152.38 f/s
# 628837: games 362, reward 18.730, eps 0.01, speed 154.36 f/s
# 630819: games 363, reward 18.730, eps 0.01, speed 155.54 f/s
# 632563: games 364, reward 18.750, eps 0.01, speed 152.87 f/s
# 634542: games 365, reward 18.740, eps 0.01, speed 152.60 f/s
# 636736: games 366, reward 18.720, eps 0.01, speed 151.36 f/s
# 638535: games 367, reward 18.750, eps 0.01, speed 152.07 f/s
# 640226: games 368, reward 18.760, eps 0.01, speed 152.03 f/s
# 641887: games 369, reward 18.830, eps 0.01, speed 154.88 f/s
# 643723: games 370, reward 18.910, eps 0.01, speed 151.40 f/s
# 645413: games 371, reward 18.910, eps 0.01, speed 154.00 f/s
# 647194: games 372, reward 18.940, eps 0.01, speed 153.82 f/s
# 648975: games 373, reward 18.960, eps 0.01, speed 155.18 f/s
# 650666: games 374, reward 18.980, eps 0.01, speed 154.03 f/s
# 652507: games 375, reward 18.980, eps 0.01, speed 152.13 f/s
# 654361: games 376, reward 18.960, eps 0.01, speed 155.52 f/s
# 656071: games 377, reward 18.970, eps 0.01, speed 154.42 f/s
# 657913: games 378, reward 19.000, eps 0.01, speed 154.34 f/s
# 659605: games 379, reward 19.010, eps 0.01, speed 154.28 f/s
# Solved!

# %%
from gymnasium.wrappers import RecordVideo
import glob
from IPython.display import Video, display

ENV_NAME = "PongNoFrameskip-v4"
VIDEO_PATH = "my_runs/video"
MODEL_PATH = sorted(glob.glob("my_runs/*.dat"))[-1]  # ostatni najlepszy model

env = make_env(ENV_NAME, render_mode="rgb_array")
env = RecordVideo(env, video_folder=VIDEO_PATH, episode_trigger=lambda x: True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

net = DQN(env.observation_space.shape, env.action_space.n).to(device)
net.load_state_dict(torch.load(MODEL_PATH, map_location=device))

state, _ = env.reset()
total_reward = 0.0

while True:
    state_v = torch.tensor(np.expand_dims(state, 0)).to(device)
    q_vals = net(state_v)
    action = torch.argmax(q_vals).item()
    state, reward, done, trunc, _ = env.step(action)
    total_reward += reward
    if done or trunc:
        break

env.close()
print(f"Total reward: {total_reward}")

video_file = glob.glob(f"{VIDEO_PATH}/*.mp4")[0]
display(Video(video_file, embed=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /content/my_runs/video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/moviepy/config_defaults.py:1: DeprecationWarning: invalid escape sequence '\P'
#   """
# Moviepy - Building video /content/my_runs/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/my_runs/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/my_runs/video/rl-video-episode-0.mp4
# Total reward: 18.0
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
import os
from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt

# === Wykres nagród z TensorBoard (trening) ===
event_files = []
for root, dirs, files in os.walk("my_runs"):
    for file in files:
        if file.startswith("events.out.tfevents"):
            event_files.append(os.path.join(root, file))

assert len(event_files) > 0, "Brak logów treningu (TensorBoard)."

ea = event_accumulator.EventAccumulator(event_files[0])
ea.Reload()

# Średnia nagroda (100 ostatnich gier)
rewards = ea.Scalars("reward_100")
steps = [s.step for s in rewards]
reward_values = [s.value for s in rewards]

plt.figure(figsize=(12, 5))
plt.plot(steps, reward_values)
plt.xlabel("Iteracja")
plt.ylabel("Średnia nagroda (100 gier)")
plt.title("Trening – średnia nagroda")
plt.grid()
plt.tight_layout()
plt.savefig("my_runs/dqn_rewards_100.png")
plt.show()

# Nagroda pojedynczej gry
rewards = ea.Scalars("reward")
steps = [s.step for s in rewards]
reward_values = [s.value for s in rewards]

plt.figure(figsize=(12, 5))
plt.plot(steps, reward_values)
plt.xlabel("Iteracja")
plt.ylabel("Nagroda")
plt.title("Trening – nagroda")
plt.grid()
plt.tight_layout()
plt.savefig("my_runs/dqn_rewards.png")
plt.show()

# Prędkość rozgrywki (klatki/s)
speed_scalars = ea.Scalars("speed")
speed_steps = [s.step for s in speed_scalars]
speed_values = [s.value for s in speed_scalars]

plt.figure(figsize=(12, 5))
plt.plot(speed_steps, speed_values)
plt.xlabel("Iteracja")
plt.ylabel("Prędkość (klatki/s)")
plt.title("Trening – prędkość rozgrywki")
plt.grid()
plt.tight_layout()
plt.savefig("my_runs/dqn_speed.png")
plt.show()

# Wartość epsilon
epsilon_scalars = ea.Scalars("epsilon")
epsilon_steps = [s.step for s in epsilon_scalars]
epsilon_values = [s.value for s in epsilon_scalars]

plt.figure(figsize=(12, 5))
plt.plot(epsilon_steps, epsilon_values)
plt.xlabel("Iteracja")
plt.ylabel("Epsilon")
plt.title("Trening – eksploracja (epsilon)")
plt.grid()
plt.tight_layout()
plt.savefig("my_runs/dqn_epsilon.png")
plt.show()
